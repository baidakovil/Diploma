# %%
import pandas as pd

# %%
df = pd.read_excel('AZS_IB.xlsx', index_col=0)

# %%
df = df.drop('текст', axis=1).join(df.текст.str.split('\n\n',expand=True).stack().reset_index(drop=True,level=1).rename('текст'))
cols = df.columns.tolist()
cols = cols[-1:] + cols[:-1]
df = df[cols]
df
# Out:
#                                                                            текст  \
# название
# device-10_20220725-082515.mp3  $ проходите пожалуйста здраствуйте здравствуйт...
# device-10_20220725-082515.mp3  # десять литров  девяносто второй первая запра...
# device-10_20220804-050950.mp3  третья девяносто второго двадцать третья колон...
# device-10_20220804-050950.mp3  здравствуйте первая топливная карта пятьдесят ...
# device-10_20220804-050950.mp3  здравствуйте четвертая девяносто пятый на тыся...
# ...                                                                          ...
# device-15_20220725-080941.mp3  клиент ушел говорите дальше вторая девяносто п...
# device-15_20220725-080941.mp3  я вас слушаю здравствуйте третья на бонусы тре...
# device-15_20220725-080941.mp3      здравствуйте здравствуйте первая пятьдесят $
# device-15_20220725-080941.mp3  раньше так не было нет  она так и делалается я...
# ...
