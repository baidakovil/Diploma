# %%
# import nltk
# nltk.download('punkt')
# nltk.download('averaged_perceptron_tagger')
# nltk.download('maxent_ne_chunker')
# nltk.download('words')
import pandas as pd
import spacy
from spacy import displacy
from collections import Counter
# !python -m spacy download en_core_web_lg
# !pip install displacy

# %%
df_fullinfo = pd.read_csv('df_fullinfo.csv', sep=';')
df_subs = pd.read_csv('df_subs.csv', sep=';')
df_fullinfo
# Out:
#       imdb_id                           moviename
# 0       76759  Star Wars: Episode IV - A New Hope  \
# 1      109830                        Forrest Gump
# 2      169547                     American Beauty
# 3      168629                  Dancer in the Dark
# 4      119116                   The Fifth Element
# ...       ...                                 ...
# 1945   236784                The Tailor of Panama
# 1946    96969          Born on the Fourth of July
# 1947   118929                           Dark City
# 1948   185937             The Blair Witch Project
# 1949   286106                               Signs
#
#                                                    data
# 0     {'MatchedBy': 'imdbid', 'IDSubMovieFile': '0',...  \
# 1     {'MatchedBy': 'imdbid', 'IDSubMovieFile': '0',...
# 2     {'MatchedBy': 'imdbid', 'IDSubMovieFile': '0',...
# 3     {'MatchedBy': 'imdbid', 'IDSubMovieFile': '0',...
# 4     {'MatchedBy': 'imdbid', 'IDSubMovieFile': '0',...
# ...

# %%
# sentence = eval(df_fullinfo[df_fullinfo.imdb_id == 75686].subs_text.item())
# sentence = ' '.join(sentence)
# sentence = "WASHINGTON -- In the wake of a string of abuses by New York police officers in the 1990s, Loretta E. Lynch, the top federal prosecutor in Brooklyn, spoke forcefully about the pain of a broken trust that African-Americans felt and said the responsibility for repairing generations of miscommunication and mistrust fell to law enforcement."
# sentence
# for sent in nltk.sent_tokenize(sentence):
#   for chunk in nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(sent))):
#      if hasattr(chunk, 'label'):
#         print(chunk.label(), ' '.join(c[0] for c in chunk))

# %%
films_to_handy = [75686,109830,76759,119116,120586,118715,88763,110413,120735,24216]
subs = df_subs[df_subs.imdb_id.isin(films_to_handy)].subs_text
filmnames = df_fullinfo[df_fullinfo.imdb_id.isin(films_to_handy)].moviename

# %%
for sentence, filmname in zip(subs, filmnames):
    doc = nlp(sentence)
    labels = [x.label_ for x in doc.ents]
    print(sum(Counter(labels).values()), filmname)
# Out:
# 362 Star Wars: Episode IV - A New Hope
# 843 Forrest Gump
# 426 The Fifth Element
# 431 American History X
# 487 Lock, Stock and Two Smoking Barrels
# 280 Leon: The Professional
# 608 Back to the Future
# 539 The Big Lebowski
# 223 King Kong
# 588 Annie Hall

# %%
sentence = sentence.replace('\n',' ')
# nlp = spacy.load('en_core_web_md')
displacy.render(nlp(sentence), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">There's an old joke.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  elderly women are at a
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Catskill Mountain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  resort.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     One
# ...

# %%
doc = nlp(sentence)
labels = [x.label_ for x in doc.ents]
sum(Counter(labels).values())
# Out:
# 589
